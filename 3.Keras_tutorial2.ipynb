# %% [markdown]
# 建立一個3層的類神經網路。
#
# *   第一層輸入為784，512個神經元，activation為ReLu的全連結層
# *   第二層為dropout層，參數為0.2
# *   輸出層輸出為10個神經元，activation為softmax(loss=categorical_crossentrop)

# %%
#模型宣告
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense, Dropout
 
model = Sequential()#模型宣告
#題目主要需要設定這三個地方
model.add(Dense(512, activation='relu', input_dim=784))
model.add(Dropout(0.2))
model.add(Dense(10, activation='softmax'))

model.compile(optimizer='adam', loss='categorical_crossentropy', metrics=['accuracy'])
 
import numpy as np
data = np.random.random((1000, 784)) 
labels = np.random.randint(10, size=(1000, 10))
 
model.fit(data, labels, epochs=10, batch_size=32)#模型訓練

score=model.evaluate(data, labels)
print(score[1])#印出資料
# Out:
# Epoch 1/10
# 32/32 [==============================] - 3s 26ms/step - loss: 476.3382 - accuracy: 0.1390
# Epoch 2/10
# 32/32 [==============================] - 1s 17ms/step - loss: 1562.8518 - accuracy: 0.1350
# Epoch 3/10
# 32/32 [==============================] - 1s 35ms/step - loss: 2825.0508 - accuracy: 0.1240
# Epoch 4/10
# 32/32 [==============================] - 1s 26ms/step - loss: 4346.4976 - accuracy: 0.1370
# Epoch 5/10
# 32/32 [==============================] - 1s 32ms/step - loss: 5546.1431 - accuracy: 0.1450
# Epoch 6/10
# 32/32 [==============================] - 1s 23ms/step - loss: 6665.6714 - accuracy: 0.1220
# Epoch 7/10
# 32/32 [==============================] - 1s 22ms/step - loss: 8621.5293 - accuracy: 0.1360
# Epoch 8/10
# 32/32 [==============================] - 1s 28ms/step - loss: 9767.0322 - accuracy: 0.1420
# Epoch 9/10
# 32/32 [==============================] - 1s 47ms/step - loss: 11349.2666 - accuracy: 0.1240
# Epoch 10/10
# ...
