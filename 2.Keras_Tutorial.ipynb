# %% [markdown]
# # Keras深度學習初體驗1
# 利用keras套件，產生一個32個神經元的深度學習模型進行訓練

# %%
#模型宣告
from tensorflow import keras
from keras.models import Sequential
from keras.layers import Dense #layers是keras的堆疊層

import numpy as np #匯入套件
data = np.random.random((1000, 10)) #隨機產生1000筆資料，每筆資料包含十個float數字
labels = np.random.randint(2, size=(1000, 1)) #隨機產生1000筆資料，每筆資料上限為2(意思就是0 或 1)
#印出資料
print(np.shape(data))
print(data[0])
print(np.shape(labels))
print(labels[0])

model = Sequential()#模型宣告
model.add(Dense(32, activation='relu', input_dim=10))#使用add的方式把設定值加入model
model.add(Dense(1, activation='sigmoid'))
model.compile(optimizer='rmsprop', loss='binary_crossentropy', metrics=['accuracy'])#模型建立好後，必須進行編譯
                                           #需要設定優化器(optimizer)、損失函數(loss function)、評量方式(metrics)

model.fit(data, labels, epochs=10, batch_size=32) #model.fit:用來訓練模型
                           #Epoch:資料訓練的次數。batch_size:一次更新的資料數量，跟gpu大小相關(預設32)。

score=model.evaluate(data, labels)
print(score[1])
# Out:
# (1000, 10)
# [0.70342755 0.72697031 0.11420711 0.10362734 0.69964912 0.96953578
#  0.9713227  0.87916044 0.45002548 0.40767878]
# (1000, 1)
# [0]
# Epoch 1/10
# 32/32 [==============================] - 1s 2ms/step - loss: 0.7068 - accuracy: 0.5190
# Epoch 2/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6939 - accuracy: 0.5150
# Epoch 3/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6925 - accuracy: 0.5170
# Epoch 4/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6921 - accuracy: 0.5190
# Epoch 5/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6914 - accuracy: 0.5320
# Epoch 6/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6910 - accuracy: 0.5310
# Epoch 7/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6911 - accuracy: 0.5290
# Epoch 8/10
# 32/32 [==============================] - 0s 2ms/step - loss: 0.6906 - accuracy: 0.5270
# Epoch 9/10
# ...
